# %% [markdown]
# Task 1

# %%
S=int(input())
L=int(input())
print("Sum =" , S+L)
print("Product =" , S*L)
print("Difference =" , S-L)
# Out:
# 4
# 5
# Sum = 9
# Product = 20
# Difference = -1

# %% [markdown]
# Task 2

# %%
import math
Radius=float(input("Please enter the radius of the circle "))
print("Area is",math.pi*(Radius**2))
print("Circumference is " ,2*math.pi*Radius)
# Out:
# Please enter the radius of the circle 4
# Area is 50.26548245743669
# Circumference is  25.132741228718345

# %% [markdown]
# Task 3

# %%
S=int(input())
L=int(input())
if S>L :
  print("First is greater")
elif L>S :
  print("Second is greater")
else :
  print("The numbers are equal")
# Out:
# 11
# 11
# The numbers are equal

# %% [markdown]
# Task 4

# %%
M=int(input())
N=int(input())
if M>N :
  print(M-N)
else :
  print(N-M)
# Out:
# -40
# -4
# 36

# %% [markdown]
# Task 5

# %%
M=int(input())
if M%2==0 :
  print("The number is even")
else :
  print("The number is odd")
# Out:
# 135
# The number is odd

# %% [markdown]
# Task 6

# %%
M=int(input())
if M%2==0 or M%5==0 :
  print(M)
else :
  print("Not a multiple of 2 OR 5")
# Out:
# 3
# Not a multiple of 2 OR 5

# %% [markdown]
# Task 7

# %%
M=int(input())
if M%2==0 and M%5==0 :
  print("Multiple of 2 and 5 both")
elif M%2==0 or M%5==0 :
  print(M)
else :
  print("Not a multiple we want")
# Out:
# 39
# Not a multiple we want

# %% [markdown]
# Task 8

# %%
M=int(input())
if M%2==0 and M%5==0 :
  print(M)
else :
  print("Not multiple of 2 and 5 both")
# Out:
# 6
# Not multiple of 2 and 5 both

# %% [markdown]
# Task 9

# %%
NS=int(input())
H= NS//3600
Mt=NS%3600
Min=Mt//60
Sec=Mt%60
print("Hours :",H,"Minutes :",Min,"Seconds :",Sec)
# Out:
# 500
# Hours : 0 Minutes : 8 Seconds : 20

# %% [markdown]
# Task 10

# %%
M=int(input())
if M>=0 and M<=168 :
  if M<=40 :
    print(M*200)
  elif  M>=40 :
    print(8000+(M-40)*300)
elif M<0 :
  print("Hours cannot be nagative")
else : 
  print("Impossible to work more than 168 hours weekly")
# Out:
# 170
# Impossible to work more than 168 hours weekly

# %% [markdown]
# Task 11

# %%
S=int(input())
if S<100 :
  print(3000-125*S*S)
elif S>=0 :
  print(12000 / (4 + (S * S)/14900))
# Out:
# 3
# 1875

# %% [markdown]
# Task 12

# %%
H=int(input())
if H>=0 and H<=23 :
  if H>=4 and H<=6 :
    print("Breakfast")
  elif H>=12 and H<=13 :
    print("Lunch") 
  elif H>=16 and H<=17 :
    print("Snacks")
  elif H>=19 and H<=20 :
    print("Dinner") 
  else :
    print("Patience is a virtue")
else :
  print("Wrong time")
# Out:
# -1
# Wrong time

# %% [markdown]
# Task 13

# %%
M=int(input())
if M>=0 and M<=100 :
  if M<50 :
    print("F")
  elif M>=50 and M<=59 :
    print("E")
  elif M>=60 and M<=69 :
    print("D")
  elif M>=70 and M<=79 :
    print("C")
  elif M>=80 and M<=89 :
    print("B")
  elif M>=90 :
    print("A")
else :
  print("The mark is invalid")
# Out:
# 111
# The mark is invalid

# %% [markdown]
# Task 14

# %%
D=int(input())
T=int(input())
C=float((D/1000)/(T/3600))
if C<60 :
  print (C,"km/h")
  print("Too slow. Needs more changes.")
elif C>=60 and C<=90 :
  print (C,"km/h")
  print("Velocity is okay. The car is ready!")
elif C>90 : 
  print (C,"km/h")
  print("Too fast. Only a few changes should suffice.")
# Out:
# 25400
# 3600
# 25.4 km/h
# Too slow. Needs more changes.

# %% [markdown]
# Task 15

# %%
M=float(input("Please enter your CGPA "))
N=int(input("Please enter the number of credits "))
if M>=3.8 and N>=30 :
  if M>=3.80 and M<=3.89 :
    print("The student is eligible for a waiver of 25 percent.")
  elif M>=3.90 and M<=3.94 :
    print("The student is eligible for a waiver of 50 percent.")
  elif M>=3.95 and M<=3.99 :
    print("The student is eligible for a waiver of 75 percent.")
  elif M==4.00 :
    print("The student is eligible for a waiver of 100 percent.")
else :
  print("The student is not eligible for a waiver")
# Out:
# Please enter your CGPA 3.79
# Please enter the number of credits 24
# The student is not eligible for a waiver

# %% [markdown]
# Task 20

# %%
M=int(input())
if not(M%2==0 or M%5==0) :
  print(M)
else :
  print("No")
# Out:
# 12
# No

# %% [markdown]
# Task 21

# %%
M=int(input())
if not(M%2==0) or not(M%5==0) :
  print(M)
else :
  print("No")
# Out:
# 14
# 14

# %% [markdown]
# Task 22

# %%
M=int(input("Enter the number of canvases : "))
N=int(input("Enter the number of bottles : "))
p=(M*120) + (N*75)
print("Previous total = " , p)
if p>=0 and p<=299 :
  print("New total after discount = " , p-0)
elif p>=300 and p<=499 :
  print("New total after discount = " , p-10)
elif p>=500 and p<=749 :
  print("New total after discount = " , p-20)
elif p>=750 and p<=999 :
  print("New total after discount = " , p-50)
elif p>=1000 :
  print("New total after discount = " , p-150)
# Out:
# Enter the number of canvases : 0
# Enter the number of bottles : 3
# Previous total =  225
# New total after discount =  225

# %% [markdown]
# Task 23

# %%
M=int(input())
c=int((M-32)*0.56)
print (c , "degrees C")
if c<20 :
  print("Winter")
elif c>20 and c<=25 :
  print("Autumn")
elif c>25 and c<30 :
  print("Spring")
elif c>=30 :
  print("Summer")
# Out:
# 76
# 24 degrees C
# Autumn
