# %% [markdown]
# Task 1

# %%
vari=input()
for a in range(len(vari)-1 , -1 , -1) :
  print(vari[a] , end="")
# Out:
# CSE110
# 011ESC

# %% [markdown]
# Task 1 (other way)

# %%
vari=input()
c= len(vari)-1
print(vari[c::-1])
# Out:
# CSE110
# 011ESC

# %% [markdown]
# Task 2

# %%
vari=input()
index=int(input())
first = vari[index: :-1]
second = vari[index+1 : : 1]
print(first+second)
# Out:
# 12345
# 2
# 32145

# %% [markdown]
# Task 3

# %%
p=input()
count=0
for a in p :
  if a=="0" or a== "1":
    count+=1
if count==len(p) :
  print("Binary Number")
else :
  print("Not a binary number")
# Out:
# 01101101101
# Binary Number

# %% [markdown]
# Task 4

# %%
M=input()
leng=len(M)
if leng<4 :
  print(M)
elif M[-2: : 1] == "er" :
  print(M[0:leng-2:1] + "est")
elif  M[-3: : 1] == "est" :
  print(M)
elif leng>4 :
  print(M + "er")
# Out:
# stronger
# strongest

# %% [markdown]
# Task 5

# %%
M=input()
sum=""
for a in M :
  sum = sum + a
  print(sum)
# Out:
# BANGLA
# B
# BA
# BAN
# BANG
# BANGL
# BANGLA

# %% [markdown]
# Task 6

# %%
M=input()
for a in M :
  print(a , ":" , ord(a))
# Out:
# Programming
# P : 80
# r : 114
# o : 111
# g : 103
# r : 114
# a : 97
# m : 109
# m : 109
# i : 105
# n : 110
# g : 103

# %% [markdown]
# Task 7

# %%
M=input()
for a in M :
  var=ord(a)
  if var>= 97 or var<=122 :
    if var==122 :
      lastvar=chr(97)
    else : 
      lastvar=chr(var+1)
  print(lastvar , end = "")
# Out:
# xyzabc
# yzabcd

# %%
a=input()
for i in a:
  if i =="z":
    print("a",end='')
  else:
    z=ord(i)+1
    print(chr(z),end='')
# Out:
# xyzabc
# yzabcd

# %%
a=input()
for i in range(1,len(a)+1,2):
  ascii=ord(a[i])-32
  ascii=chr(ascii)
  print(ascii,end='')
# Out:
# string
# TIG

# %%
a=input()
for i in range(len(a)):
  if i==0:
    print(a[i],end='')
  elif a[i]!=a[i-1]:
    print(a[i],end='')
# Out:
# aaabbbbcccccccc
# abc

# %%
a=input()
for i in range(len(a)):
  if a[i]==",":
    c=a[:i]
    d=a[i+2:]
e=c+d
s=''
count=1
count1=1
for p in range(len(e)):
  s+=c[p:count]
  count+=1
  s+=d[p:count1]
  count1+=1
print(s)
# Out:
# ABCD, efgh
# AeBfCgDh

# %% [markdown]
# Task 8

# %%
M=input()
var=len(M)
for a in range(var) :
  if a%2==0 :
    pass
  else : 
    print(M[a].upper())
# Out:
# string
# T
# I
# G

# %%
M=input()
for i in range (len(M)) :
  if i==0:
    print(M[0],end="")
  elif M[i]!=M[i-1] :
    print(M[i],end="")
# Out:
# AAABBBBCDDBBECE
# ABCDBECE

# %%
i = 10
while(i >= -20):
    if(i < 0):
        test = " != "
        test = str(i//2) + test + str(int(i/2))
    else:
        test = " == "
        test = str(i//2) + test + str(int(i/2))
    print(test)
    i -= 5
# Out:
# 5 == 5
# 2 == 2
# 0 == 0
# -3 != -2
# -5 != -5
# -8 != -7
# -10 != -10
