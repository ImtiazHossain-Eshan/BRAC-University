# %% [markdown]
# Task 1

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# Task 2

# %%
print (54+56)
# Out:
# 110

# %% [markdown]
# Task 3

# %%
season = 'Fall'
year=2022

print(season)
print(year)
# Out:
# Fall
# 2022

# %% [markdown]
# Task 4

# %%
name = input()
print ("your name is " , name)
# Out:
# John
# your name is  John

# %% [markdown]
# Task 5

# %%
M=int(input())
N=int(input())
print(M,"^",N,":",M**N)
# Out:
# 2
# 3
# 2 ^ 3 : 8

# %% [markdown]
# Task 6

# %%
M=int(input())

print(M-(M%4))
# Out:
# 9
# 8

# %% [markdown]
# Task 7

# %%
M = input()
N = input ()
print (N + M)
# Out:
# Hello
# World
# WorldHello

# %% [markdown]
# Task 8

# %%
a=input()
print(a[0])
# Out:
# The quick brown fox jumps over the lazy dog
# T

# %% [markdown]
# Task 10

# %%
a= int(input())
b= int(input())
c= int(input())
d= float(input())
print (int(a**c+b*a-d/3))
# Out:
# 2
# 6
# 8
# 1.3
# 267
