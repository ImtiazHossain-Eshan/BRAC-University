# %%
#Task 1
my_list = [10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]
for i in range(len(my_list)-1):
    for j in range(len(my_list) - i - 1):
        if my_list[j] > my_list[j+1]:
            temp = my_list[j]
            my_list[j] = my_list[j+1]
            my_list[j+1] = temp
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task 1 alt way
my_list = [10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]
i=0
while i< len(my_list) : 
    for j in range(len(my_list) - i - 1):
        if my_list[j] > my_list[j+1]:
            temp = my_list[j]
            my_list[j] = my_list[j+1]
            my_list[j+1] = temp
    i+=1
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task 1 alt way
my_list = [10,1,20,3,6,2,5,11,15,2,12,14,17,18,29]
def sorts(my_list) :
  for i in range(1,len(my_list)):
    for j in range(1,len(my_list)+1-i):
        if my_list[j] < my_list[j-1]:
            my_list[j-1],my_list[j]=my_list[j],my_list[j-1]
sorts(my_list)
print(my_list)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task 2
n= [10, 1, 20, 3, 6, 2, 5, 11, 15, 2, 12, 14, 17, 18, 29]
def m(n) :
  for i in range(len(n)) :
    s=i
    for j in range(i+1,len(n)) :
      if n[j]<n[s] :
        s=j
    n[i],n[s]=n[s],n[i]
m(n)
print(n)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task 2 alt way
n=[10, 1, 20, 3, 6, 2, 5, 11, 15, 2, 12, 14, 17, 18, 29]
for i in range(len(n)) :
  for j in range(i+1,len(n)) :
    if n[j]<n[i] :
      n[i],n[j]=n[j],n[i]
print(n)
# Out:
# [1, 2, 2, 3, 5, 6, 10, 11, 12, 14, 15, 17, 18, 20, 29]

# %%
#Task 3 with bubble
m=[10, 1, 20, 3, 6, 2, 5, 11, 15, 2, 12, 14, 17, 18, 29]
def n(m) :
    for i in range(1,len(m)):
     for j in range(1,len(m)+1-i):
        if m[j] > m[j-1]:
            m[j-1],m[j]=m[j],m[j-1]
n(m)
print(m)
# Out:
# [29, 20, 18, 17, 15, 14, 12, 11, 10, 6, 5, 3, 2, 2, 1]

# %%
#Task 4
m=[10,30,20,70,11,15,22,16,58,100,12,56,70,80]
even=m[::2]
odd=m[1::2]
m.clear()
for i in range(len(even)) :
  for j in range(i+1,len(even)) :
    if even[j]<even[i] :
      even[i],even[j]=even[j],even[i]
for i in range(len(odd)) :
  for j in range(i+1,len(odd)) :
    if odd[j]>odd[i] :
      odd[i],odd[j]=odd[j],odd[i]
for i in range (len(even)) :
  m.append(even[i])
  m.append(odd[i])
print(m)
# Out:
# [10, 100, 11, 80, 12, 70, 20, 56, 22, 30, 58, 16, 70, 15]

# %%
#Task 5
m={"CSE110":1,"PHY111:":2,"MAT110":3}
n= [ ["Alan", 95, 87, 91], ["Turing", 92, 90, 83], ["Elon", 87, 92, 80], ["Musk", 85, 94, 90] ]
L=input()
L=val[L]
for i in range (len(n)) :
  for j in range (i+1,len()) :
