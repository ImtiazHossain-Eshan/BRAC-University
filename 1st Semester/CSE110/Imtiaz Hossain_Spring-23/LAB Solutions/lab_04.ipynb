# %%
# TAsk 1
string=input("Enter a string ")
for i in range(len(string)-1,-1,-1):
 print(string[i],end="")
print()

#or
for i in range(-1,-len(string)-1,-1):
 print(string[i],end="")
print()

# or
print(string[::-1])
# Out:
# Enter a string cse110
# 011esc
# 011esc
# 011esc

# %%
#TASK 2
st=input("Enter a string more than length 1:  ")
ind=int(input("Enter starting index "))
for i in range(ind,-1,-1):
  print(st[i],end="")
for i in range(ind+1,len(st)):
  print(st[i],end="")
print()

# or
print(st[ind::-1],end="")
print(st[ind+1:])
# Out:
# Enter a string more than length 1:  1234567
# Enter starting index 3
# 4321567
# 4321567

# %%
# The else block just after for is executed only when the loop is NOT terminated by a break statement.

# %%
# Task 3
string=input("Enter something ")
for char in string:
  if char!="0" and char!="1":
    print("Not a binary number")
    break
else:
  print("Binary number")
# Out:
# Enter something 0160001
# Not a binary number

# %%
# Task 4
word=input("Enter a word ")
if word.endswith("est"):
  print(word)
elif word.endswith("er"):
  word=word.rstrip("er")
  print(word+"est")
elif len(word)<4:
  print(word)
else:
  print(word+"er")
# Out:
# Enter a word ber
# best

# %%
# Task 5
word=input("Enter a word ")
for i in range(0,len(word)):
  for j in range(0,i+1):
    print(word[j],end="")
  print()
# Out:
# Enter a word BANGLA
# B
# BA
# BAN
# BANG
# BANGL
# BANGLA

# %%
# TAsk 6
word=input("Enter a word ")
for i in word:
  print(f"{i} : {ord(i)}")
# Out:
# Enter a word hunger
# h : 104
# u : 117
# n : 110
# g : 103
# e : 101
# r : 114

# %%
#Task 7
word=input("Enter a word in lowercase ")
for i in word:
  if i=="z":
    print("a",end="")
  else:
    print(chr(ord(i)+1),end="")
# Out:
# Enter a word in lowercase the cow
# uif!dpx

# %%
# Task 8
word=input("Enter a word ")
nword=word[1::2]  #[start:end:step]
out=''
for i in nword:
  if 97<=ord(i)<=122:
    out+=(chr(ord(i)-32))
  elif 65<=ord(i)<=90:
    out+=i
print(out)
# Out:
# Enter a word string
# TIG

# %%
# Task 9    
st=input("enter a word ")
char=st[0]               # Important
out=st[0]
for i in range(1,len(st)):
  if char==st[i]:
    continue
  else:
    out+=st[i]
    char=st[i]

  
print(out)
# Out:
# enter a word AaAAaaaaAAa
# AaAaAa

# %%
n=input()
m=''
for i in range(len(n)-1):
  if n[i] != n[i+1] :
    m+=n[i]

print(m,end='')
print(n[-1])
# Out:
# AaAAaaaaAAa
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-645ece73b04d> in <module>
#       2 m=''
#       3 for i in range(len(n)):
# ----> 4   if n[i] != n[i+1] :
#       5     m+=n[i]
#       6
#
# IndexError: string index out of range

# %%
# Task 10
string=input("enter ")
comma=string.find(",")
st1=string[:comma]
st2=string[comma+1:]
if len(st1)==len(st2):
  for i in range(len(st1)):
    print(st1[i]+st2[i],end="")
else:
  if len(st1)>len(st2):
    for i in range(len(st2)):
     print(st1[i]+st2[i],end="")
    print(st1[len(st2):])
  else:
    for i in range(len(st1)):
      print(st1[i]+st2[i],end="")
    print(st2[len(st1):])

# or

string=input("enter ")
comma=string.find(",")
st1=string[:comma]
st2=string[comma+1:]

if len(st1)>len(st2):
  for i in range(len(st2)):
   print(st1[i]+st2[i],end="")
  print(st1[len(st2):])
else:
  for i in range(len(st1)):
    print(st1[i]+st2[i],end="")
  print(st2[len(st1):])
# Out:
# enter ABCD,efgh
# AeBfCgDhenter ABCD,efgh
# AeBfCgDh

# %%
st='alpha'
print(st[-1:])
# Out:
# a

# %%
# TAsk 16 Important
st=input("Enter a string: ")
let=input("Enter a letter you want to remove: ")
new_st=''
j=0
if let in st:
  for i in range(len(st)):
    if st[i]==let:
      continue
    else:
      new_st+=st[i]
  print(new_st)
else:
  if len(st)>3:
    print(st[1:len(st)-1])
  else:
    print(st)
# Out:
# Enter a string: hi
# Enter a letter you want to remove: a
# hi

# %%
#Task 17
st=input("Enter a string: ")
split=input("Enter spilting character: ")
j=0
for i in range(len(st)):
  if st[i]==split:
    print(st[j:i])
    j=i+1
print(st[j:])
# Out:
# Enter a string tom@gmail,harry@yahoo,bob@gmail,mary@gmail
# Enter spilting character ,
# tom@gmail
# harry@yahoo
# bob@gmail
# mary@gmail

# %%
#Task 18
st=input("Enter a string ")
n=int(input("Enter a number "))
if n%2==0:
  print(st*(n*2))
else:
  print(st*(n*3))
# Out:
# Enter a string CSE110
# Enter a number 3
# CSE110CSE110CSE110CSE110CSE110CSE110CSE110CSE110CSE110

# %%
# Task 19
st=input("Enter a string ")
new_st=''
m=0
if 97<=ord(st[0])<=122:
  new_st=chr(ord(st[0])-32)
elif 65<=ord(st[0])<=90:
  new_st=st[0]

for i in range(1,len(st)):
  if 65<=ord(new_st[-1])<=90:
    if 97<=ord(st[i])<=122:
     new_st+=st[i]
    elif 65<=ord(st[i])<=90:
     new_st+=chr(ord(st[i])+32)
    else:
      new_st+=st[i]
  elif 97<=ord(new_st[-1])<=122:
    if 97<=ord(st[i])<=122:
      new_st+=chr(ord(st[i])-32)
    elif 65<=ord(st[i])<=90:
      new_st+=st[i]
    else:
      new_st+=st[i]
      
  else:
      if 65<=ord(new_st[-m])<=90:
        if 97<=ord(st[i])<=122:
         new_st+=st[i]
        elif 65<=ord(st[i])<=90:
         new_st+=chr(ord(st[i])+32)
        new_st+=st[i]
      
    


print(new_st)
# Out:
# Enter a string Python programming is very easy
# PyThOn pRoGrAmMiNg iS vErY eAsY

# %%
print(chr(45))
print(chr(45)+chr(8))
# Out:
# -
# -

# %%
print("aplphaq")
print(chr(45)+chr(8))
print("ALPHAQ")
# Out:
# aplphaq
# -
# ALPHAQ
