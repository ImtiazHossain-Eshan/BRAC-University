# %%
print("Hello World")
# Out:
# hello world

# %%
print(54+56)
# Out:
# 110

# %%
print(2**3)
# Out:
# 8

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(-10/3)
# Out:
# -3.3333333333333335

# %%
print(10//3)
# Out:
# 3

# %%
print(-10//3)
# Out:
# -4

# %%
print(2%-10)
# Out:
# -8

# %%
season="Fall"
year=2022

print(season)
print(year)
# Out:
# Fall2022

# %%
name=input("Enter your name\n")
print("Your name is",name)
# Out:
# Enter your name
# Zunaid
# Your name is Zunaid

# %%
number=int(input("Enter base number\n"))
power=int(input("Enter its power\n"))
print(f"{number}^{power}:{number**power}")
# Out:
# Enter base number
# 5
# Enter its power
# 2
# 5^2:25

# %%
totalW= int(input("Enter total weight of shipment\n"))
a= totalW//4
maxload= a*4
print("Maximum load is",maxload)
# Out:
# Enter total weight of shipment
# 23
# Maximum load is 20

# %%
totalW= int(input("Enter total weight of shipment\n"))
maxload= totalW-totalW%4
print("Maximum load is",maxload)
# Out:
# Enter total weight of shipment
# 23
# Maximum load is 20

# %%
a=input("Enter something\n")
b=input("Enter something\n")
c=b+a

print(c)
# Out:
# Enter something
# Hello
# Enter something
# World
# WorldHello

# %%
line=input("Write a line\n")
print(line[0])
# Out:
# Write a line
# Python is an intepreted language
# P

# %%
num=int(input("Enter a number\n"))
if num%2==0:
  print(True)
else:
  print(False)
# Out:
# Enter a number
# 44
# True

# %%
A=int(input("Entrer a number\n"))
B=int(input("Entrer a number\n"))
C=int(input("Entrer a number\n"))
D=float(input("Entrer a number\n"))
ans=int((A**C)+(B*A)-(D/3))
print(ans)
# Out:
# Entrer a number
# 9
# Entrer a number
# 100
# Entrer a number
# 1
# Entrer a number
# 3.7
# 907

# %%
total=int(input("Enter total number of chocolates you have\n"))
friend=total//3
you=total%3
print(f"Each friend will recieve {friend} chocolates")
print(f"The number of remaining chocolates {you}")
# Out:
# Enter total number of chocolates you have
# 50
# Each friend will recieve 16 chocolates
# The number of remaining chocolates 2

# %%
print(79%2)
# Out:
# 1
