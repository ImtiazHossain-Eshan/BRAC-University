# %%
#Task1
a_tuple = ("The Institute", ("Best Mystery & Thriller", "The Silent Patient", 68821), 75717,
[1, 2, 3, 400, 5, 6, 7], ("Best Fiction", "The Testaments", 98291))
print(a_tuple[3][3])
# Out:
# 400

# %%
#Task2
m=input()
l=[]
n=m[1:len(m)-1:1]
g=n.split(",")
for i in g :
  l+=[int(i)]
if len(l)>=4 :
   ramisa=l[2:len(l)-2:1]
   tupli=tuple(ramisa)
   print(tupli)
# Out:
# (10, 20, 24, 25, 26, 35, 70)
# (24, 25, 26)

# %%
#Task 3
book_info = (
("Best Mystery & Thriller","The Silent Patient",68,821),
("Best Horror","The Institute",75,717),
("Best History & Biography","The five",31,783 ),
("Best Fiction","The Testaments",98,291)
)
length=len(book_info)
print("Size of the tuple :", length)
for i in book_info :
  print(i)
# Out:
# Size of the tuple : 4
# ('Best Mystery & Thriller', 'The Silent Patient', 68, 821)
# ('Best Horror', 'The Institute', 75, 717)
# ('Best History & Biography', 'The five', 31, 783)
# ('Best Fiction', 'The Testaments', 98, 291)

# %%
#Task 4
n= (
("Best Mystery & Thriller","The Silent Patient",68821),
("Best Horror","The Institute",75717),
("Best History & Biography","The five",31783 ),
("Best Fiction","The Testaments",98291)
)
for i in n :
  a,b,c,=i
  print(b, "won the", a, "category with" , c  ,"votes")
# Out:
# The Silent Patient won the Best Mystery & Thriller category with 68821 votes
# The Institute won the Best Horror category with 75717 votes
# The five won the Best History & Biography category with 31783 votes
# The Testaments won the Best Fiction category with 98291 votes

# %%
n= (
("Best Mystery & Thriller","The Silent Patient",68821),
("Best Horror","The Institute",75717),
("Best History & Biography","The five",31783 ),
("Best Fiction","The Testaments",98291)
)
for a,b,c in n :
  print(f"{b} won the '{a}' catwegory with {c} votes")
# Out:
# The Silent Patient won the 'Best Mystery & Thriller' catwegory with 68821 votes
# The Institute won the 'Best Horror' catwegory with 75717 votes
# The five won the 'Best History & Biography' catwegory with 31783 votes
# The Testaments won the 'Best Fiction' catwegory with 98291 votes

# %%
#Task5
m= (10, 8, 5, 2, 10, 15, 10, 8, 5, 8, 8, 2)
n=int(input())
count=0
for a in m :
  if n==a :
    count+=1
print(n,"appears",count,"times in the tuple")
# Out:
# 8
# 8 appears 4 times in the tuple

# %%
#Task6
m=('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h')
n=list(m)
q=n[len(n)-1::-1]
d=tuple(q)
print(d)
# Out:
# ('h', 'g', 'f', 'e', 'd', 'c', 'b', 'a')

# %%
m=('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h')
n=list(m)
l=[]
for i in range(len(n)-1,-1,-1) :
  l.append(m[i])
d=tuple(l)
print(d)
# Out:
# ('h', 'g', 'f', 'e', 'd', 'c', 'b', 'a')

# %%
#Task7
p1={'Harry':15, 'Draco':8, 'Nevil':19}
q1={'Ginie':18, 'Luna': 14}
my={}
for a,b in p1.items() :
  my[a]=b
for j,i in q1.items() :
  my[j]=i
print(my)
# Out:
# {'Harry': 15, 'Draco': 8, 'Nevil': 19, 'Ginie': 18, 'Luna': 14}

# %%
#Task8
m=input()
m=m.strip("{}")
l=m.split(",")
s=len(l)
sum=0
for i in l :
  w=i.split(":")
  sum+=int(w[1])
print(f"Average is {int(sum/s)}")
# Out:
# {'Jon': 100, 'Dan': 200, 'Rob':300}
# Average is 200

# %%
#Task 8 in
m=input()
m=m.strip("{}")
l=m.split(",")
s=len(l)
sum=[]
for i in l :
  w=i.split(":")
  for a in w :
    sum.append(a)
q=dict(sum)
print(q)
# Out:
# {'Jon': 100, 'Dan': 200, 'Rob':300}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e351986d23c9> in <module>
#       9   for a in w :
#      10     sum.append(a)
# ---> 11 q=dict(sum)
#      12 print(q)
#      13
#
# ValueError: dictionary update sequence element #0 has length 5; 2 is required

# %%
#Task 9
t=int(input())
d={}
m= {'Cierra Vega': 175, 'Alden Cantrell': 200, 'Kierra Gentry': 165, 'Pierre Cox': 190}
for i,j in m.items() :
  if j >= t :
    d[i]=j
print(d)
# Out:
# 190
# {'Alden Cantrell': 200, 'Pierre Cox': 190}

# %%
#Task 10
m={'sci fi': 12, 'mystery': 15, 'horror': 8, 'mythology': 10, 'young_adult': 4, 'adventure':14}
d={}
maxi=0
for i,j in m.items():
  if j> maxi :
    maxi=j
for a,b in m.items() :
  if b== maxi :
    print(f"The highest selling book genre is'{a}'and the number of books sold are{maxi}")
# Out:
# The highest selling book genre is'mystery'and the number of books sold are15

# %%
#Task 11
m=input()
l={}
n=m[1:len(m)-1]
e=n.lower()
for i in e : 
  if i in l :
    l[i]+=1
  elif i== " " :
    continue
  else :
    l[i]=1
print(l)
# Out:
# "Python programming is fun"
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 3, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 2, 's': 1, 'f': 1, 'u': 1}

# %%
#Task 12
m={'A': [1, 2, 3], 'b': ['1', '2'], "c": [4, 5, 6, 7]}
count=0
for a in m.values() :
  for b in a :
    count+=1
print(count)
# Out:
# 9

# %%
#Task 13
m=[("a", 1), ("b", 2), ("a", 3), ("b", 1), ("a", 2), ("c", 1)]
n=tuple(m)
l={}
for a,b in n :
  if a in l :
    l[a]+=[b]
  else :
    l[a]=[b]
print(l)
# Out:
# {'a': [1, 3, 2], 'b': [2, 1], 'c': [1]}
