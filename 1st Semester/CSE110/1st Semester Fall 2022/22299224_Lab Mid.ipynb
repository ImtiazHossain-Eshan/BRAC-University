# %%
M=input()
if len(M) ==17 :
  for a in range (2,len(M)-3,3) :
    if M[a]== "-" or M[a] == ":" :
      if ord(M[a])>=48 or ord(M[a])<=57 :
        if ord(M[a])>=65 or ord(M[a])<=70 :
          print("Valid")
    else :
          print("Invalid")
# Out:
# 00-07-E9-63-CE-5B
# Valid
# Valid
# Valid
# Valid
